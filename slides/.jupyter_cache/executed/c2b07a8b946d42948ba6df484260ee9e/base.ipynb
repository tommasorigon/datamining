# %%
# imports
import os
import sys
import types
import json

# figure size/format
fig_width = 10
fig_height = 5
fig_format = 'retina'
fig_dpi = 96

# matplotlib defaults / format
try:
  import matplotlib.pyplot as plt
  plt.rcParams['figure.figsize'] = (fig_width, fig_height)
  plt.rcParams['figure.dpi'] = fig_dpi
  plt.rcParams['savefig.dpi'] = fig_dpi
  from IPython.display import set_matplotlib_formats
  set_matplotlib_formats(fig_format)
except Exception:
  pass

# plotly use connected mode
try:
  import plotly.io as pio
  pio.renderers.default = "notebook_connected"
except Exception:
  pass

# enable pandas latex repr when targeting pdfs
try:
  import pandas as pd
  if fig_format == 'pdf':
    pd.set_option('display.latex.repr', True)
except Exception:
  pass



# output kernel dependencies
kernel_deps = dict()
for module in list(sys.modules.values()):
  # Some modules play games with sys.modules (e.g. email/__init__.py
  # in the standard library), and occasionally this can cause strange
  # failures in getattr.  Just ignore anything that's not an ordinary
  # module.
  if not isinstance(module, types.ModuleType):
    continue
  path = getattr(module, "__file__", None)
  if not path:
    continue
  if path.endswith(".pyc") or path.endswith(".pyo"):
    path = path[:-1]
  if not os.path.exists(path):
    continue
  kernel_deps[path] = os.stat(path).st_mtime
print(json.dumps(kernel_deps))

# set run_path if requested
if r'/Users/tommaso/Library/Mobile Documents/com~apple~CloudDocs/University/Didattica/Data Mining/datamining/slides':
  os.chdir(r'/Users/tommaso/Library/Mobile Documents/com~apple~CloudDocs/University/Didattica/Data Mining/datamining/slides')

# reset state
# %reset

def ojs_define(**kwargs):
  import json
  try:
    # IPython 7.14 preferred import
    from IPython.display import display, HTML
  except:
    from IPython.core.display import display, HTML

  # do some minor magic for convenience when handling pandas
  # dataframes
  def convert(v):
    try:
      import pandas as pd
    except ModuleNotFoundError: # don't do the magic when pandas is not available
      return v
    if type(v) == pd.Series:
      v = pd.DataFrame(v)
    if type(v) == pd.DataFrame:
      j = json.loads(v.T.to_json(orient='split'))
      return dict((k,v) for (k,v) in zip(j["index"], j["data"]))
    else:
      return v
  
  v = dict(contents=list(dict(name=key, value=convert(value)) for (key, value) in kwargs.items()))
  display(HTML('<script type="ojs-define">' + json.dumps(v) + '</script>'), metadata=dict(ojs_define = True))
globals()["ojs_define"] = ojs_define
# Out:
# /var/folders/fx/_f2m8c1d0xd7mqykb5_gcqdr0000gn/T/ipykernel_30334/3048206622.py:20: DeprecationWarning:
#
# `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
# {"/Users/tommaso/opt/anaconda3/lib/python3.9/importlib/_bootstrap.py": 1669107983.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/importlib/_bootstrap_external.py": 1669107983.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/codecs.py": 1669107978.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/encodings/aliases.py": 1669107984.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/encodings/__init__.py": 1669107984.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/encodings/utf_8.py": 1669107985.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/encodings/latin_1.py": 1669107985.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/abc.py": 1669107978.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/io.py": 1669107979.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/stat.py": 1669107979.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/_collections_abc.py": 1669107978.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/genericpath.py": 1669107978.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/posixpath.py": 1669107979.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/os.py": 1669107979.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/_sitebuiltins.py": 1669107978.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/_bootlocale.py": 1669107978.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/site-packages/_distutils_hack/__init__.py": 1669270133.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/types.py": 1669107979.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/warnings.py": 1669107979.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/importlib/__init__.py": 1669107983.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/importlib/machinery.py": 1669107983.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/lib-dynload/_heapq.cpython-39-darwin.so": 1669108033.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/heapq.py": 1669107979.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/keyword.py": 1669107979.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/operator.py": 1669107979.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/reprlib.py": 1669107979.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/collections/__init__.py": 1669107984.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/collections/abc.py": 1669107984.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/functools.py": 1669107978.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/contextlib.py": 1669107978.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/enum.py": 1669107978.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/sre_constants.py": 1669107979.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/sre_parse.py": 1669107979.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/sre_compile.py": 1669107979.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/copyreg.py": 1669107978.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/re.py": 1669107979.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/typing.py": 1669107979.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/importlib/abc.py": 1669107983.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/importlib/util.py": 1669107983.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/site-packages/sphinxcontrib/__init__.py": 1607574933.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/site-packages/zope/__init__.py": 1607554565.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/site.py": 1669107979.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/_weakrefset.py": 1669107978.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/weakref.py": 1669107979.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/pkgutil.py": 1669107979.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/runpy.py": 1669107979.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/site-packages/ipykernel/_version.py": 1673315491.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/lib-dynload/_json.cpython-39-darwin.so": 1669108029.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/json/scanner.py": 1669107986.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/json/decoder.py": 1669107986.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/json/encoder.py": 1669107986.0, "/Users/tommaso/opt/anaconda3/lib/python3.9/json/__init__. ...

# %%
import pandas as pd
ames = pd.read_csv("https://datasciencebocconi.github.io/Data/AmesHousing.csv")
ames.head(3)
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2   NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# 0        0       5    2010       WD           Normal     215000
# 1        0       6    2010       WD           Normal     105000
# 2    12500       6    2010       WD           Normal     172000
#
# [3 rows x 82 columns]

# %%
ames.columns
# Out:
# Index(['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
#        'Fireplaces', 'Fireplace Qu', 'Garage Type', 'Garage Yr Blt',
#        'Garage Finish', 'Garage Cars', 'Garage Area', 'Garage Qual',
#        'Garage Cond', 'Paved Drive', 'Wood Deck SF', 'Open Porch SF',
#        'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Pool QC',
#        'Fence', 'Misc Feature', 'Misc Val', 'Mo Sold', 'Yr Sold', 'Sale Type',
#        'Sale Condition', 'SalePrice'],
#       dtype='object')
